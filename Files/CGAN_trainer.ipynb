# %%
import numpy as np
import pandas as pd
from numpy import load
from numpy import zeros
from numpy import ones
from numpy import asarray
from numpy import append
from numpy.random import random
from numpy.random import randint
from numpy.random import shuffle
import time
import os
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Concatenate
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
from matplotlib import patheffects as path_effects
import collections
from tensorflow.keras.models import load_model
from tensorflow import get_logger as log
# Out:
# Using TensorFlow backend.

# %%
# !pip install -q pydot
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-ab401ca1a5d1> in <module>()
# ----> 1 get_ipython().system('pip install -q pydot')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# --> 438       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     439   shell.user_ns['_exit_code'] = result.returncode
#     440   if -result.returncode in _INTERRUPTED_SIGNALS:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     179
#     180     with temporary_clearer(), _display_stdin_widget(
# --> 181         delay_millis=500) as update_stdin_widget:
#     182       # TODO(b/115531839): Ensure that subprocesses are terminated upon
#     183       # interrupt.
#
# /usr/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _display_stdin_widget(delay_millis)
#     339   shell = _ipython.get_ipython()
#     340   display_args = ['cell_display_stdin', {'delayMillis': delay_millis}]
# --> 341   _message.blocking_request(*display_args, parent=shell.parent_header)
#     342
#     343   def echo_updater(new_echo_status):
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     169   # unique.
#     170   request_id = send_request(request_type, request, parent=parent)
# --> 171   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: CustomError: Timed out waiting for iframe configuration. URL: https://colab.research.google.com/drive/1jkWS7ePbX_NPTWG97WzL5-SDjLLHJB4d#scrollTo=N2TRZpeE9rNU

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
os.chdir("/content/drive/My Drive/deeplearning/")
# !ls
# Out:
# cgan				      img_align_celeba_attractive_face.npz
# gan_model.png			      img_align_celeba_attractive_full.npz
# ids_align_celeba_attractive_face.npz  list_attr_celeba.csv
# ids_align_celeba_attractive_full.npz  results

# %%
#  SET YOUR FLAGS
qErrorHide = False
if qErrorHide:
    print("\n***REMEMBER:  WARNINGS turned OFF***\n***REMEMBER:  WARNINGS turned OFF***\n")
    log().setLevel('ERROR')

# %%
#    INDICATE IF STARTING FRESH OR CONTINUING FROM PREVIOUS RUN
qRestart = False
if qRestart:
    epochs_done = 85
    epochs_goal = 200
else:
    epochs_done = 0
    epochs_goal = 100

# %%
# define the standalone discriminator model
def define_discriminator(in_shape=(80,80,3), n_classes=4):
    print("**********  ENTERED discriminator  *****************")
    ##### foundation for labels
    in_label = Input(shape=(1,))
    embedding_layer = Embedding(n_classes, 8)
    # embedding_layer.trainable = False
    li = embedding_layer (in_label)
    n_nodes = in_shape[0] * in_shape[1]
    print(">>embedding>> in_shape[0], in_shape[1], n_nodes: ", in_shape[0], in_shape[1], n_nodes)
    li = Dense(n_nodes)(li)
    li = Reshape((in_shape[0], in_shape[1], 1))(li)
    # image input
    dropout = 0.1
    in_image = Input(shape=in_shape)
    print("\nin_image: ", in_image)
    # concat label as a channel
    merge = Concatenate()([in_image, li])
    print("\nmerge.shape: ", merge.shape)
    # sample to 80x80
    fe = Conv2D(128, (5,5), padding='same')(merge)
    fe = LeakyReLU(alpha=0.2)(fe)
    fe = Dropout(dropout)(fe)
    print("fe.shape: ", fe.shape)
    # downsample to 40x40
    fe = Conv2D(128, (5,5), strides=(2,2), padding='same')(fe)
    fe = LeakyReLU(alpha=0.2)(fe)
    # fe = Dropout(dropout)(fe)
    print("fe.shape: ", fe.shape)
    # downsample to 20x20
    fe = Conv2D(128, (5,5), strides=(2,2), padding='same')(fe)
    fe = LeakyReLU(alpha=0.2)(fe)
    # fe = Dropout(dropout)(fe)
    print("fe.shape: ", fe.shape)
    # downsample to 10x10
    fe = Conv2D(128, (5,5), strides=(2,2), padding='same')(fe)
    fe = LeakyReLU(alpha=0.2)(fe)
    # fe = Dropout(dropout)(fe)
    print("fe.shape: ", fe.shape)
    # downsample to 5x5
    fe = Conv2D(128, (5,5), strides=(2,2), padding='same')(fe)
    fe = LeakyReLU(alpha=0.2)(fe)
    # fe = Dropout(dropout)(fe)
    print("fe.shape: ", fe.shape)
    # flatten feature maps
    fe = Flatten()(fe)
    # fe = Dropout(dropout)(fe)
    print("fe flatten shape: ", fe.shape)
    # output
    out_layer = Dense(1, activation='sigmoid')(fe)
    print("out_layer.shape: ", out_layer.shape)
    # define model
    model = Model([in_image, in_label], out_layer)
    print("\nmodel: ", model)
    # compile model
    opt = Adamax(lr=0.00007, beta_1=0.08, beta_2=0.999, epsilon=10e-8)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    print("\nembedding_layer.get_weights(): \n",embedding_layer.get_weights())
    model.summary()
    plot_model(model, to_file='cgan/discriminator_model.png')
    return model

# %%
# define the standalone generator model
def define_generator(latent_dim, n_classes=4):
    print("**********  ENTERED generator  *****************")
    ##### foundation for labels
    in_label = Input(shape=(1,))
    embedding_layer = Embedding(n_classes, 8)
    embedding_layer.trainable = True
    li = embedding_layer (in_label)
    n_nodes = 5 * 5
    li = Dense(n_nodes)(li)
    li = Reshape((5 , 5, 1))(li)
    print("generator...  n_nodes, li.shape: ", n_nodes, li.shape)
    ##### foundation for 5x5 image
    in_lat = Input(shape=(latent_dim,))
    n_nodes = 128 * 5 * 5
    genX = Dense(n_nodes)(in_lat)
    genX = LeakyReLU(alpha=0.2)(genX)
    genX = Reshape((5, 5, 128))(genX)
    dropout = 0.1
    print("genX.shape: ", genX.shape)
    ##### merge image gen and label input
    merge = Concatenate()([genX, li])
    print("merge.shape: ", merge.shape)
    ##### create merged model
    # upsample to 10x10
    gen = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')(merge)
    print("gen after CV2DT.shape: ", gen.shape)
    gen = LeakyReLU(alpha=0.2)(gen)
    gen = Dropout(dropout)(gen)
    print("gen.shape: ", gen.shape)
    # upsample to 20x20
    gen = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')(gen)
    gen = LeakyReLU(alpha=0.2)(gen)
    print("gen.shape: ", gen.shape)
    # upsample to 40x40
    gen = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')(gen)
    gen = LeakyReLU(alpha=0.2)(gen)
    print("gen.shape: ", gen.shape)
    # upsample to 80x80
    gen = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')(gen)
    gen = LeakyReLU(alpha=0.2)(gen)
    print("gen.shape: ", gen.shape)
    # output layer 80x80x3
    out_layer = Conv2D(3, (5,5), activation='tanh', padding='same')(gen)
    print("out_layer.shape: ", out_layer.shape)
    # define model
    model = Model(inputs=[in_lat, in_label], outputs=out_layer)
    opt = Adamax(lr=0.0002, beta_1=0.5, beta_2=0.999, epsilon=10e-8)
    model.compile(loss=['binary_crossentropy'], optimizer=opt)
    print("\nembedding_layer.get_weights(): \n",embedding_layer.get_weights())
    model.summary()
    #plot_model(model, to_file='generator_model.png')
    return model

# %%
# define the combined generator and discriminator model, for updating the generator
def define_gan(g_model, d_model):
    print("**********  ENTERED gan  *****************")
    # make weights in the discriminator not trainable
    d_model.trainable = False
    # get noise and label inputs from generator model
    gen_noise, gen_label = g_model.input
    # get image output from the generator model
    gen_output = g_model.output
    # connect image output and label input from generator as inputs to discriminator
    gan_output = d_model([gen_output, gen_label])
    # define gan model as taking noise and label and outputting a classification
    model = Model([gen_noise, gen_label], gan_output)
    # compile model
    opt = Adamax(lr=0.0002, beta_1=0.5, beta_2=0.999, epsilon=10e-8)
    model.compile(loss='binary_crossentropy', optimizer=opt)
    model.summary()
    plot_model(model, to_file='gan_model.png')
    return model

# %%
# assign categories
def assign_categs(df, lenrows):
    print("\n*****  ATTRIBUTES: \n", df.mean())

    face_male = df['Male']
    print("face_male: ", face_male.mean())
    face_male = np.where(face_male > 0, 1, face_male)
    print("face_male: ", face_male.mean())

    face_high_cheekbones = df['High_Cheekbones']
    print("face_high_cheekbones: ", face_high_cheekbones.mean())
    face_high_cheekbones = np.where(face_high_cheekbones > 0, 1, face_high_cheekbones)
    print("face_high_cheekbones: ", face_high_cheekbones.mean())

    face_big_lips = df['Big_Lips']
    print("face_big_lips: ", face_big_lips.mean())
    face_big_lips = np.where(face_big_lips > 0, 1, face_big_lips)
    print("face_big_lips: ", face_big_lips.mean())

    # replace vectors with category value
    categs = np.zeros(lenrows, dtype=int)
    print("categ.mean()): ", categs.mean())
    categs = np.where(face_male > 0, 1, categs)
    print("add face_male: categs.mean()): ", categs.mean())
    categs = np.where((face_high_cheekbones > 0)&(categs==0), 2, categs)
    print("add high_cheekbones: categs.mean()): ", categs.mean())
    categs = np.where((face_big_lips > 0)&(categs==0), 3, categs)
    print("add big lips: categs.mean()): ", categs.mean())
    print("\ncategs: \n", categs)
    return categs

# %%
def get_cumProbs(freqCategs, categs):
    freqLists = [freqCategs[i][1] for i in range(len(freqCategs))]
    freqListX = asarray(freqLists, dtype=np.float32)
    print("freqListX: ", freqListX)
    print("len(categs): ", len(categs))
    cumProbs = freqListX/len(categs)
    print("cumProbs: ", cumProbs)
    cumProbs = append((0.0),cumProbs)
    for i in range(len(cumProbs)-1):
        cumProbs[i+1]=cumProbs[i]+cumProbs[i+1]
    print("cumProbs: ", cumProbs)
    return cumProbs

# %%
def load_real_samples():
    # load the face dataset
    data = load('img_align_celeba_attractive_face.npz')
    X = data['arr_0']
    # convert from unsigned ints to floats
    X = X.astype('float32')
    # scale from [0,255] to [-1,1]
    X = (X - 127.5) / 127.5
    data = pd.read_csv('list_attr_celeba.csv', nrows=100000)
    data = data.drop("image_id",axis=1)
    ids  = load('ids_align_celeba_attractive_face.npz')
    idsX = ids['arr_0']
    dataX = list()
    for i,id in enumerate(idsX):
        dataVal = data[id:id+1].values
        dataVal = np.where(dataVal==-1, 0, dataVal)
        dataX.append(dataVal)
    cols = data.columns
    lencols = len(cols)
    print("cols: ", cols)
    lenrows = len(dataX)
    dataVals = asarray(dataX[0:]).reshape((lenrows,lencols),)
    df = pd.DataFrame(data=dataVals,columns=cols)
    pd.options.display.float_format = '{:,.3f}'.format
    categs = assign_categs(df, lenrows)
    freqCategs = list(collections.Counter(sorted(categs)).items())
    print("freqCategs: ", freqCategs)
    cumProbs = get_cumProbs(freqCategs, categs)
    return [X, categs], cumProbs

# %%
# select real samples
def generate_real_samples(dataset, n_samples):
    # split into images and labels
    images, labels = dataset
    # choose random instances
    ix = randint(0, images.shape[0], n_samples)
    # retrieve selected images
    X, labels = images[ix], labels[ix]
    # generate 'real' class labels (1)
    y = ones((n_samples, 1))
    return [X, labels], y

# %%
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples, cumProbs, n_classes=4):
    # print("generate_latent_points: ", latent_dim, n_samples)
    initX = -3.0
    rangeX = 2.0*abs(initX)
    stepX = rangeX / (latent_dim * n_samples)
    x_input = asarray([initX + stepX*(float(i)) for i in range(0,latent_dim * n_samples)])
    shuffle(x_input)
    # generate points in the latent space
    z_input = x_input.reshape(n_samples, latent_dim)
    randx = random(n_samples)
    labels = np.zeros(n_samples, dtype=int)
    for i in range(n_classes):
        labels = np.where((randx >= cumProbs[i]) & (randx < cumProbs[i+1]), i, labels)
    return [z_input, labels]

# %%
# use the generator to generate n fake examples, with class labels
def generate_fake_samples(generator, latent_dim, n_samples, cumProbs):
    # generate points in latent space
    z_input, labels_input = generate_latent_points(latent_dim, n_samples, cumProbs)
    # predict outputs
    images = generator.predict([z_input, labels_input])
    # create class labels
    y = zeros((n_samples, 1))
    return [images, labels_input], y

# %%
# create and save a plot of generated images
def save_plot(examples, labels, epoch, n=10):
    # scale from [-1,1] to [0,1]
    examples = (examples + 1) / 2.0
    # plot images
    for i in range(n * n):
        # define subplot
        fig = plt.subplot(n, n, 1 + i)
        strLabel = str(labels[i])
        # turn off axis
        fig.axis('off')
        fig.text(8.0,20.0,strLabel, fontsize=6, color='white')
        # plot raw pixel data
        fig.imshow(examples[i])
    # save plot to file
    filename = 'results/generated_plot_e%03d.png' % (epoch+1)
    plt.savefig(filename)
    plt.close()

# %%
def save_real_plots(dataset, nRealPlots = 5, n=10, n_samples=100):
    # plot images
    for epoch in range(nRealPlots):
        if epoch%5==0:
            print("real_plots: ", epoch)
        # prepare real samples
        [X_real, labels], y_real = generate_real_samples(dataset, n_samples)
        # scale from [-1,1] to [0,1]
        X_real = (X_real + 1) / 2.0
        for i in range(n * n):
            # define subplot
            fig = plt.subplot(n, n, 1 + i)
            strLabel = str(labels[i])
            # fig.title = strLabel
            # turn off axis
            fig.axis('off')
            fig.text(8.0,20.0,strLabel, fontsize=6, color='white')
            # plot raw pixel data
            fig.imshow(X_real[i])
        # save plot to file
        filename = 'results/real_plots/real_plot_e%03d.png' % (epoch+1)
        plt.savefig(filename)
        plt.close()

# %%
# evaluate the discriminator, plot generated images, save generator model
def summarize_performance(epoch, g_model, d_model, gan_model, dataset, latent_dim, n_samples=100):
    # prepare real samples
    [X_real, labels_real], y_real = generate_real_samples(dataset, n_samples)
    # evaluate discriminator on real examples
    _, acc_real = d_model.evaluate([X_real, labels_real], y_real, verbose=0)
    # prepare fake examples
    [X_fake, labels], y_fake = generate_fake_samples(g_model, latent_dim, n_samples, cumProbs)
    # evaluate discriminator on fake examples
    _, acc_fake = d_model.evaluate([X_fake, labels], y_fake, verbose=0)
    # summarize discriminator performance
    print('>Accuracy real: %.0f%%, fake: %.0f%%' % (acc_real*100, acc_fake*100))
    # save plot
    save_plot(X_fake, labels, epoch)
    # save the generator model tile file
    filename = 'results/generator_model_%03d.h5' % (epoch+1)
    g_model.save(filename)
    filename = 'results/generator_model_gan%03d.h5' % (epoch+1)
    gan_model.save(filename)
    filename = 'results/generator_model_dis%03d.h5' % (epoch+1)
    d_model.trainable = True
    for layer in d_model.layers:
        layer.trainable = True
    d_model.save(filename)
    d_model.trainable = False
    for layer in d_model.layers:
        layer.trainable = False

# %%
def restart(epochs_done):
    # gen_weights = array(model.get_weights())
    print("****  PULLING IN EPOCH: ", epochs_done)
    filename = 'results/generator_model_dis%03d.h5' % (epochs_done)
    d_model = load_model(filename, compile=True)
    d_model.trainable = True
    for layer in d_model.layers:
        layer.trainable = True
    d_model.summary()
    filename = 'results/generator_model_%03d.h5' % (epochs_done)
    g_model = load_model(filename, compile=True)
    g_model.summary()
    gan_model = define_gan(g_model, d_model)
    gan_model.summary()
    return d_model, g_model, gan_model

# %%
# train the generator and discriminator
def train(g_model, d_model, gan_model, dataset, latent_dim, epochs_goal=100, n_batch=128, epochs_done=1):
    nTryAgains = 0
    nTripsOnSameSavedWts = 0
    nSaves = 0
    bat_per_epo = int(dataset[0].shape[0] / n_batch)
    half_batch = int(n_batch / 2)
    d_trainable_weights = np.array(d_model.get_weights())
    g_trainable_weights = np.array(g_model.get_weights())
    gan_trainable_weights = np.array(gan_model.get_weights())
    now = time.time()
    ij = 0
    ijSave = -100
    # manually enumerate epochs
    for i in range(epochs_done, epochs_goal):
        # enumerate batches over the training set
        for j in range(bat_per_epo):
            ij+=1
            # get randomly selected 'real' samples
            [X_real, labels_real], y_real = generate_real_samples(dataset, half_batch)
            qDebug=False
            # update discriminator model weights
            dis_loss, _ = d_model.train_on_batch([X_real, labels_real], y_real)
            [X_fake, labels], y_fake = generate_fake_samples(g_model, latent_dim, half_batch, cumProbs)
            gen_loss, _ = d_model.train_on_batch([X_fake, labels], y_fake)
            [z_input, labels_input] = generate_latent_points(latent_dim, n_batch, cumProbs)
            # create inverted labels for the fake samples
            y_gan = ones((n_batch, 1))
            # update the generator via the discriminator's error
            gan_loss = gan_model.train_on_batch([z_input, labels_input], y_gan)
            # summarize loss on this batch
            if (j+1) % 5==0 or dis_loss > 1.10 or gen_loss > 1.10 or gan_loss > 1.80:
                diff = int(time.time()-now)
                print('>%d/%d, %d/%d, d1=%.3f, d2=%.3f, g=%.3f, secs=%d, tryAgain=%d, nTripsOnSameSavedWts=%d, nSaves=%d' %
                    (i+1, epochs_goal, j+1, bat_per_epo, dis_loss, gen_loss, gan_loss, diff, nTryAgains, nTripsOnSameSavedWts, nSaves))
            if dis_loss > 0.30 and dis_loss < 0.95 and gen_loss > 0.25 and gen_loss < 0.95 and gan_loss > 0.40 and gan_loss < 1.50:
                nTripsOnSameSavedWts = 0
                if ij - ijSave > 8:
                    nSaves+=1
                    ijSave = ij
                    d_trainable_weights = np.array(d_model.get_weights())
                    g_trainable_weights = np.array(g_model.get_weights())
                    gan_trainable_weights = np.array(gan_model.get_weights())
            if (dis_loss < 0.001 or dis_loss > 2.0) and ijSave > 0:
                nTryAgains+=1
                nTripsOnSameSavedWts+=1
                print("LOADING d_model",j+1," from ",ijSave)
                d_model.set_weights(d_trainable_weights)
            if (gen_loss < 0.001 or gen_loss > 2.0) and ijSave > 0:
                nTryAgains+=1
                nTripsOnSameSavedWts+=1
                print("LOADING g_model",j+1," from ",ijSave)
                g_model.set_weights(g_trainable_weights)
            if (gan_loss < 0.010 or gan_loss > 4.50) and ijSave > 0:
                nTryAgains+=1
                nTripsOnSameSavedWts+=1
                print("LOADING gan_models",j+1," from ",ijSave)
                gan_model.set_weights(gan_trainable_weights)
            # if (j+1) % 10 == 0:
                # summarize_performance(i, g_model, d_model, dataset, latent_dim)
            if nTripsOnSameSavedWts > 20:
                print("**********  Too many rebuilds  **************")
                summarize_performance(i, g_model, d_model, dataset, latent_dim)
                import sys
                sys.exit(0)
        # evaluate the model performance, sometimes
        if (i+1) % 1 == 0:
            summarize_performance(i, g_model, d_model, gan_model, dataset, latent_dim)

# %%
# size of the latent space
latent_dim = 100

if qRestart:
        d_model, g_model, gan_model = restart(epochs_done = epochs_done)
else:
        # create the discriminator
        d_model = define_discriminator()
        #d_model = load_model("generator_model_dis001.h5")
        # create the generator
        #g_model = load_model("generator_model_001.h5")
        g_model = define_generator(latent_dim)
        # create the gan
        gan_model = define_gan(g_model, d_model)
        #gan_model = load_model("generator_model_gan001.h5")

# load image data
dataset, cumProbs = load_real_samples()
save_real_plots(dataset, nRealPlots=2)
train(g_model, d_model, gan_model,  dataset, latent_dim, epochs_goal=epochs_goal, n_batch=128, epochs_done=epochs_done)
# Out:
# Streaming output truncated to the last 5000 lines.
# >137/200, 290/390, d1=0.613, d2=0.682, g=0.823, secs=8828, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2243
# >137/200, 295/390, d1=0.681, d2=0.659, g=0.856, secs=8830, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2243
# >137/200, 300/390, d1=0.672, d2=0.655, g=0.873, secs=8833, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2244
# >137/200, 305/390, d1=0.637, d2=0.632, g=0.862, secs=8835, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2244
# >137/200, 310/390, d1=0.614, d2=0.633, g=0.853, secs=8837, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2245
# >137/200, 315/390, d1=0.663, d2=0.635, g=0.876, secs=8839, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2245
# >137/200, 320/390, d1=0.662, d2=0.646, g=0.836, secs=8841, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2246
# >137/200, 325/390, d1=0.656, d2=0.654, g=0.869, secs=8843, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2246
# >137/200, 330/390, d1=0.622, d2=0.661, g=0.833, secs=8846, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2247
# >137/200, 335/390, d1=0.677, d2=0.665, g=0.857, secs=8848, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2248
# >137/200, 340/390, d1=0.635, d2=0.646, g=0.849, secs=8850, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2248
# >137/200, 345/390, d1=0.706, d2=0.656, g=0.856, secs=8852, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2249
# >137/200, 350/390, d1=0.636, d2=0.646, g=0.835, secs=8854, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2249
# >137/200, 355/390, d1=0.630, d2=0.668, g=0.847, secs=8856, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2250
# >137/200, 360/390, d1=0.643, d2=0.659, g=0.855, secs=8858, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2250
# >137/200, 365/390, d1=0.643, d2=0.624, g=0.837, secs=8861, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2251
# >137/200, 370/390, d1=0.656, d2=0.649, g=0.866, secs=8863, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2251
# >137/200, 375/390, d1=0.670, d2=0.664, g=0.870, secs=8865, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2252
# >137/200, 380/390, d1=0.650, d2=0.641, g=0.849, secs=8867, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2253
# >137/200, 385/390, d1=0.675, d2=0.661, g=0.822, secs=8869, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2253
# >137/200, 390/390, d1=0.629, d2=0.671, g=0.829, secs=8871, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2254
# >Accuracy real: 56%, fake: 77%
# >138/200, 5/390, d1=0.629, d2=0.641, g=0.893, secs=8875, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2254
# >138/200, 10/390, d1=0.687, d2=0.676, g=0.852, secs=8878, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2255
# >138/200, 15/390, d1=0.690, d2=0.627, g=0.871, secs=8880, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2255
# >138/200, 20/390, d1=0.670, d2=0.678, g=0.842, secs=8882, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2256
# >138/200, 25/390, d1=0.632, d2=0.656, g=0.847, secs=8884, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2256
# >138/200, 30/390, d1=0.663, d2=0.666, g=0.857, secs=8886, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2257
# >138/200, 35/390, d1=0.650, d2=0.663, g=0.815, secs=8888, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2258
# >138/200, 40/390, d1=0.644, d2=0.679, g=0.824, secs=8890, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2258
# >138/200, 45/390, d1=0.658, d2=0.638, g=0.854, secs=8893, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2259
# >138/200, 50/390, d1=0.668, d2=0.629, g=0.827, secs=8895, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2259
# >138/200, 55/390, d1=0.632, d2=0.675, g=0.826, secs=8897, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2260
# >138/200, 60/390, d1=0.666, d2=0.709, g=0.859, secs=8899, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2260
# >138/200, 65/390, d1=0.688, d2=0.636, g=0.852, secs=8901, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2261
# >138/200, 70/390, d1=0.697, d2=0.686, g=0.863, secs=8903, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2261
# >138/200, 75/390, d1=0.667, d2=0.652, g=0.825, secs=8906, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2262
# >138/200, 80/390, d1=0.623, d2=0.678, g=0.856, secs=8908, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2263
# >138/200, 85/390, d1=0.634, d2=0.696, g=0.819, secs=8910, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2263
# >138/200, 90/390, d1=0.657, d2=0.642, g=0.833, secs=8912, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2264
# >138/200, 95/390, d1=0.659, d2=0.640, g=0.854, secs=8914, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2264
# >138/200, 100/390, d1=0.682, d2=0.644, g=0.861, secs=8916, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2265
# >138/200, 105/390, d1=0.652, d2=0.655, g=0.858, secs=8918, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2265
# >138/200, 110/390, d1=0.686, d2=0.654, g=0.856, secs=8921, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2266
# >138/200, 115/390, d1=0.667, d2=0.658, g=0.835, secs=8923, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2266
# >138/200, 120/390, d1=0.628, d2=0.658, g=0.874, secs=8925, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2267
# >138/200, 125/390, d1=0.661, d2=0.618, g=0.834, secs=8927, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2268
# >138/200, 130/390, d1=0.689, d2=0.675, g=0.815, secs=8929, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2268
# >138/200, 135/390, d1=0.656, d2=0.665, g=0.827, secs=8931, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2269
# >138/200, 140/390, d1=0.641, d2=0.684, g=0.847, secs=8934, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2269
# >138/200, 145/390, d1=0.647, d2=0.682, g=0.867, secs=8936, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2270
# >138/200, 150/390, d1=0.630, d2=0.670, g=0.868, secs=8938, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2270
# >138/200, 155/390, d1=0.678, d2=0.649, g=0.853, secs=8940, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2271
# >138/200, 160/390, d1=0.691, d2=0.634, g=0.850, secs=8942, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2271
# >138/200, 165/390, d1=0.616, d2=0.660, g=0.828, secs=8944, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2272
# >138/200, 170/390, d1=0.615, d2=0.691, g=0.808, secs=8946, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2273
# >138/200, 175/390, d1=0.659, d2=0.668, g=0.870, secs=8949, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2273
# >138/200, 180/390, d1=0.693, d2=0.646, g=0.859, secs=8951, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2274
# >138/200, 185/390, d1=0.685, d2=0.639, g=0.826, secs=8953, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2274
# >138/200, 190/390, d1=0.608, d2=0.728, g=0.853, secs=8955, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2275
# >138/200, 195/390, d1=0.673, d2=0.666, g=0.862, secs=8957, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2275
# >138/200, 200/390, d1=0.649, d2=0.663, g=0.853, secs=8959, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2276
# >138/200, 205/390, d1=0.680, d2=0.664, g=0.858, secs=8962, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2276
# >138/200, 210/390, d1=0.695, d2=0.675, g=0.835, secs=8964, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2277
# >138/200, 215/390, d1=0.665, d2=0.628, g=0.881, secs=8966, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2278
# >138/200, 220/390, d1=0.675, d2=0.669, g=0.831, secs=8968, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2278
# >138/200, 225/390, d1=0.670, d2=0.664, g=0.847, secs=8970, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2279
# >138/200, 230/390, d1=0.696, d2=0.630, g=0.857, secs=8972, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2279
# >138/200, 235/390, d1=0.679, d2=0.655, g=0.838, secs=8974, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2280
# >138/200, 240/390, d1=0.647, d2=0.646, g=0.828, secs=8977, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2280
# >138/200, 245/390, d1=0.655, d2=0.650, g=0.865, secs=8979, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2281
# >138/200, 250/390, d1=0.677, d2=0.695, g=0.875, secs=8981, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2281
# >138/200, 255/390, d1=0.708, d2=0.667, g=0.850, secs=8983, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2282
# >138/200, 260/390, d1=0.674, d2=0.661, g=0.864, secs=8985, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2283
# >138/200, 265/390, d1=0.689, d2=0.639, g=0.832, secs=8987, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2283
# >138/200, 270/390, d1=0.700, d2=0.613, g=0.853, secs=8990, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2284
# >138/200, 275/390, d1=0.639, d2=0.659, g=0.835, secs=8992, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2284
# >138/200, 280/390, d1=0.705, d2=0.720, g=0.859, secs=8994, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2285
# >138/200, 285/390, d1=0.683, d2=0.631, g=0.867, secs=8996, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2285
# >138/200, 290/390, d1=0.692, d2=0.644, g=0.830, secs=8998, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2286
# >138/200, 295/390, d1=0.613, d2=0.674, g=0.896, secs=9000, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2286
# >138/200, 300/390, d1=0.685, d2=0.667, g=0.831, secs=9002, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2287
# >138/200, 305/390, d1=0.671, d2=0.624, g=0.891, secs=9005, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2288
# >138/200, 310/390, d1=0.626, d2=0.640, g=0.810, secs=9007, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2288
# >138/200, 315/390, d1=0.621, d2=0.718, g=0.853, secs=9009, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2289
# >138/200, 320/390, d1=0.691, d2=0.644, g=0.867, secs=9011, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2289
# >138/200, 325/390, d1=0.660, d2=0.647, g=0.826, secs=9013, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2290
# >138/200, 330/390, d1=0.626, d2=0.655, g=0.842, secs=9015, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2290
# >138/200, 335/390, d1=0.680, d2=0.632, g=0.869, secs=9018, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2291
# >138/200, 340/390, d1=0.659, d2=0.645, g=0.881, secs=9020, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2291
# >138/200, 345/390, d1=0.619, d2=0.685, g=0.816, secs=9022, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2292
# >138/200, 350/390, d1=0.635, d2=0.656, g=0.857, secs=9024, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2293
# >138/200, 355/390, d1=0.648, d2=0.656, g=0.876, secs=9026, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2293
# >138/200, 360/390, d1=0.639, d2=0.693, g=0.842, secs=9028, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2294
# >138/200, 365/390, d1=0.695, d2=0.645, g=0.878, secs=9030, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2294
# >138/200, 370/390, d1=0.644, d2=0.680, g=0.868, secs=9033, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2295
# >138/200, 375/390, d1=0.646, d2=0.641, g=0.829, secs=9035, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2295
# >138/200, 380/390, d1=0.656, d2=0.671, g=0.848, secs=9037, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2296
# >138/200, 385/390, d1=0.662, d2=0.663, g=0.846, secs=9039, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2296
# >138/200, 390/390, d1=0.688, d2=0.653, g=0.857, secs=9041, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2297
# >Accuracy real: 51%, fake: 82%
# >139/200, 5/390, d1=0.665, d2=0.662, g=0.864, secs=9045, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2298
# >139/200, 10/390, d1=0.639, d2=0.672, g=0.859, secs=9048, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2298
# >139/200, 15/390, d1=0.661, d2=0.684, g=0.827, secs=9050, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2299
# >139/200, 20/390, d1=0.685, d2=0.655, g=0.852, secs=9052, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2299
# >139/200, 25/390, d1=0.675, d2=0.658, g=0.855, secs=9054, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2300
# >139/200, 30/390, d1=0.671, d2=0.670, g=0.860, secs=9056, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2300
# >139/200, 35/390, d1=0.645, d2=0.642, g=0.835, secs=9058, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2301
# >139/200, 40/390, d1=0.694, d2=0.670, g=0.831, secs=9060, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2301
# >139/200, 45/390, d1=0.632, d2=0.648, g=0.815, secs=9063, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2302
# >139/200, 50/390, d1=0.674, d2=0.627, g=0.871, secs=9065, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2303
# >139/200, 55/390, d1=0.624, d2=0.687, g=0.831, secs=9067, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2303
# >139/200, 60/390, d1=0.647, d2=0.638, g=0.842, secs=9069, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2304
# >139/200, 65/390, d1=0.658, d2=0.663, g=0.837, secs=9071, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2304
# >139/200, 70/390, d1=0.691, d2=0.638, g=0.856, secs=9073, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2305
# >139/200, 75/390, d1=0.627, d2=0.641, g=0.855, secs=9076, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2305
# >139/200, 80/390, d1=0.620, d2=0.654, g=0.852, secs=9078, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2306
# >139/200, 85/390, d1=0.670, d2=0.664, g=0.837, secs=9080, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2306
# >139/200, 90/390, d1=0.680, d2=0.664, g=0.874, secs=9082, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2307
# >139/200, 95/390, d1=0.616, d2=0.651, g=0.851, secs=9084, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2308
# >139/200, 100/390, d1=0.691, d2=0.658, g=0.852, secs=9086, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2308
# >139/200, 105/390, d1=0.637, d2=0.680, g=0.845, secs=9089, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2309
# >139/200, 110/390, d1=0.618, d2=0.649, g=0.827, secs=9091, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2309
# >139/200, 115/390, d1=0.671, d2=0.628, g=0.846, secs=9093, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2310
# >139/200, 120/390, d1=0.681, d2=0.662, g=0.856, secs=9095, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2310
# >139/200, 125/390, d1=0.655, d2=0.651, g=0.865, secs=9097, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2311
# >139/200, 130/390, d1=0.663, d2=0.684, g=0.841, secs=9099, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2311
# >139/200, 135/390, d1=0.669, d2=0.642, g=0.842, secs=9101, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2312
# >139/200, 140/390, d1=0.646, d2=0.639, g=0.877, secs=9104, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2313
# >139/200, 145/390, d1=0.678, d2=0.675, g=0.852, secs=9106, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2313
# >139/200, 150/390, d1=0.686, d2=0.636, g=0.843, secs=9108, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2314
# >139/200, 155/390, d1=0.641, d2=0.676, g=0.839, secs=9110, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2314
# >139/200, 160/390, d1=0.695, d2=0.670, g=0.836, secs=9112, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2315
# >139/200, 165/390, d1=0.655, d2=0.656, g=0.817, secs=9114, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2315
# >139/200, 170/390, d1=0.687, d2=0.622, g=0.864, secs=9117, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2316
# >139/200, 175/390, d1=0.675, d2=0.633, g=0.858, secs=9119, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2316
# >139/200, 180/390, d1=0.636, d2=0.669, g=0.848, secs=9121, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2317
# >139/200, 185/390, d1=0.600, d2=0.706, g=0.835, secs=9123, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2318
# >139/200, 190/390, d1=0.647, d2=0.651, g=0.833, secs=9125, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2318
# >139/200, 195/390, d1=0.662, d2=0.635, g=0.857, secs=9127, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2319
# >139/200, 200/390, d1=0.674, d2=0.679, g=0.830, secs=9129, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2319
# >139/200, 205/390, d1=0.656, d2=0.657, g=0.835, secs=9132, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2320
# >139/200, 210/390, d1=0.682, d2=0.622, g=0.898, secs=9134, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2320
# >139/200, 215/390, d1=0.649, d2=0.653, g=0.845, secs=9136, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2321
# >139/200, 220/390, d1=0.633, d2=0.663, g=0.861, secs=9138, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2321
# >139/200, 225/390, d1=0.697, d2=0.666, g=0.850, secs=9140, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2322
# >139/200, 230/390, d1=0.646, d2=0.666, g=0.827, secs=9142, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2323
# >139/200, 235/390, d1=0.626, d2=0.633, g=0.889, secs=9145, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2323
# >139/200, 240/390, d1=0.632, d2=0.659, g=0.846, secs=9147, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2324
# >139/200, 245/390, d1=0.633, d2=0.700, g=0.855, secs=9149, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2324
# >139/200, 250/390, d1=0.715, d2=0.655, g=0.853, secs=9151, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2325
# >139/200, 255/390, d1=0.656, d2=0.682, g=0.865, secs=9153, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2325
# >139/200, 260/390, d1=0.684, d2=0.664, g=0.845, secs=9155, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2326
# >139/200, 265/390, d1=0.649, d2=0.691, g=0.885, secs=9157, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2326
# >139/200, 270/390, d1=0.645, d2=0.665, g=0.842, secs=9160, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2327
# >139/200, 275/390, d1=0.687, d2=0.676, g=0.853, secs=9162, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2328
# >139/200, 280/390, d1=0.634, d2=0.625, g=0.858, secs=9164, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2328
# >139/200, 285/390, d1=0.616, d2=0.656, g=0.849, secs=9166, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2329
# >139/200, 290/390, d1=0.681, d2=0.682, g=0.876, secs=9168, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2329
# >139/200, 295/390, d1=0.659, d2=0.622, g=0.872, secs=9170, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2330
# >139/200, 300/390, d1=0.675, d2=0.663, g=0.853, secs=9172, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2330
# >139/200, 305/390, d1=0.670, d2=0.629, g=0.831, secs=9175, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2331
# >139/200, 310/390, d1=0.640, d2=0.651, g=0.820, secs=9177, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2331
# >139/200, 315/390, d1=0.658, d2=0.671, g=0.841, secs=9179, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2332
# >139/200, 320/390, d1=0.734, d2=0.664, g=0.849, secs=9181, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2333
# >139/200, 325/390, d1=0.658, d2=0.631, g=0.867, secs=9183, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2333
# >139/200, 330/390, d1=0.624, d2=0.672, g=0.857, secs=9185, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2334
# >139/200, 335/390, d1=0.687, d2=0.666, g=0.840, secs=9187, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2334
# >139/200, 340/390, d1=0.650, d2=0.632, g=0.843, secs=9190, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2335
# >139/200, 345/390, d1=0.656, d2=0.686, g=0.844, secs=9192, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2335
# >139/200, 350/390, d1=0.639, d2=0.649, g=0.849, secs=9194, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2336
# >139/200, 355/390, d1=0.700, d2=0.672, g=0.866, secs=9196, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2336
# >139/200, 360/390, d1=0.659, d2=0.653, g=0.856, secs=9198, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2337
# >139/200, 365/390, d1=0.647, d2=0.661, g=0.851, secs=9200, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2338
# >139/200, 370/390, d1=0.651, d2=0.643, g=0.852, secs=9202, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2338
# >139/200, 375/390, d1=0.647, d2=0.647, g=0.857, secs=9205, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2339
# >139/200, 380/390, d1=0.659, d2=0.694, g=0.875, secs=9207, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2339
# >139/200, 385/390, d1=0.689, d2=0.641, g=0.826, secs=9209, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2340
# >139/200, 390/390, d1=0.676, d2=0.674, g=0.833, secs=9211, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2340
# >Accuracy real: 45%, fake: 82%
# >140/200, 5/390, d1=0.644, d2=0.657, g=0.828, secs=9215, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2341
# >140/200, 10/390, d1=0.657, d2=0.641, g=0.833, secs=9217, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2341
# >140/200, 15/390, d1=0.661, d2=0.644, g=0.833, secs=9220, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2342
# >140/200, 20/390, d1=0.625, d2=0.672, g=0.861, secs=9222, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2343
# >140/200, 25/390, d1=0.666, d2=0.657, g=0.848, secs=9224, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2343
# >140/200, 30/390, d1=0.640, d2=0.620, g=0.873, secs=9226, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2344
# >140/200, 35/390, d1=0.629, d2=0.664, g=0.843, secs=9228, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2344
# >140/200, 40/390, d1=0.607, d2=0.675, g=0.832, secs=9230, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2345
# >140/200, 45/390, d1=0.630, d2=0.678, g=0.891, secs=9232, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2345
# >140/200, 50/390, d1=0.673, d2=0.638, g=0.885, secs=9235, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2346
# >140/200, 55/390, d1=0.674, d2=0.661, g=0.851, secs=9237, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2346
# >140/200, 60/390, d1=0.680, d2=0.730, g=0.858, secs=9239, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2347
# >140/200, 65/390, d1=0.636, d2=0.658, g=0.868, secs=9241, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2348
# >140/200, 70/390, d1=0.637, d2=0.673, g=0.847, secs=9243, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2348
# >140/200, 75/390, d1=0.651, d2=0.709, g=0.835, secs=9245, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2349
# >140/200, 80/390, d1=0.658, d2=0.631, g=0.857, secs=9247, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2349
# >140/200, 85/390, d1=0.681, d2=0.648, g=0.839, secs=9250, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2350
# >140/200, 90/390, d1=0.646, d2=0.631, g=0.849, secs=9252, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2350
# >140/200, 95/390, d1=0.659, d2=0.658, g=0.863, secs=9254, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2351
# >140/200, 100/390, d1=0.670, d2=0.677, g=0.830, secs=9256, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2351
# >140/200, 105/390, d1=0.663, d2=0.655, g=0.813, secs=9258, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2352
# >140/200, 110/390, d1=0.632, d2=0.640, g=0.832, secs=9260, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2353
# >140/200, 115/390, d1=0.703, d2=0.673, g=0.843, secs=9262, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2353
# >140/200, 120/390, d1=0.671, d2=0.670, g=0.856, secs=9265, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2354
# >140/200, 125/390, d1=0.675, d2=0.641, g=0.842, secs=9267, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2354
# >140/200, 130/390, d1=0.648, d2=0.680, g=0.827, secs=9269, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2355
# >140/200, 135/390, d1=0.712, d2=0.659, g=0.845, secs=9271, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2355
# >140/200, 140/390, d1=0.647, d2=0.625, g=0.888, secs=9273, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2356
# >140/200, 145/390, d1=0.683, d2=0.624, g=0.835, secs=9275, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2356
# >140/200, 150/390, d1=0.654, d2=0.651, g=0.834, secs=9278, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2357
# >140/200, 155/390, d1=0.666, d2=0.607, g=0.865, secs=9280, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2358
# >140/200, 160/390, d1=0.664, d2=0.663, g=0.837, secs=9282, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2358
# >140/200, 165/390, d1=0.627, d2=0.631, g=0.861, secs=9284, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2359
# >140/200, 170/390, d1=0.663, d2=0.624, g=0.872, secs=9286, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2359
# >140/200, 175/390, d1=0.678, d2=0.650, g=0.859, secs=9288, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2360
# >140/200, 180/390, d1=0.656, d2=0.667, g=0.846, secs=9290, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2360
# >140/200, 185/390, d1=0.670, d2=0.645, g=0.845, secs=9293, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2361
# >140/200, 190/390, d1=0.687, d2=0.650, g=0.861, secs=9295, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2361
# >140/200, 195/390, d1=0.640, d2=0.705, g=0.850, secs=9297, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2362
# >140/200, 200/390, d1=0.667, d2=0.652, g=0.871, secs=9299, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2363
# >140/200, 205/390, d1=0.680, d2=0.645, g=0.862, secs=9301, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2363
# >140/200, 210/390, d1=0.645, d2=0.651, g=0.817, secs=9303, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2364
# >140/200, 215/390, d1=0.617, d2=0.644, g=0.860, secs=9305, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2364
# >140/200, 220/390, d1=0.676, d2=0.695, g=0.834, secs=9308, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2365
# >140/200, 225/390, d1=0.616, d2=0.637, g=0.858, secs=9310, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2365
# >140/200, 230/390, d1=0.677, d2=0.658, g=0.867, secs=9312, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2366
# >140/200, 235/390, d1=0.632, d2=0.653, g=0.875, secs=9314, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2366
# >140/200, 240/390, d1=0.662, d2=0.649, g=0.870, secs=9316, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2367
# >140/200, 245/390, d1=0.663, d2=0.662, g=0.823, secs=9318, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2368
# >140/200, 250/390, d1=0.685, d2=0.657, g=0.855, secs=9320, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2368
# >140/200, 255/390, d1=0.649, d2=0.651, g=0.849, secs=9323, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2369
# >140/200, 260/390, d1=0.671, d2=0.666, g=0.847, secs=9325, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2369
# >140/200, 265/390, d1=0.658, d2=0.638, g=0.832, secs=9327, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2370
# >140/200, 270/390, d1=0.600, d2=0.660, g=0.858, secs=9329, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2370
# >140/200, 275/390, d1=0.679, d2=0.663, g=0.857, secs=9331, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2371
# >140/200, 280/390, d1=0.685, d2=0.638, g=0.837, secs=9333, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2371
# >140/200, 285/390, d1=0.662, d2=0.662, g=0.844, secs=9335, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2372
# >140/200, 290/390, d1=0.672, d2=0.657, g=0.843, secs=9338, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2373
# >140/200, 295/390, d1=0.654, d2=0.646, g=0.852, secs=9340, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2373
# >140/200, 300/390, d1=0.664, d2=0.658, g=0.866, secs=9342, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2374
# >140/200, 305/390, d1=0.651, d2=0.655, g=0.855, secs=9344, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2374
# >140/200, 310/390, d1=0.668, d2=0.663, g=0.839, secs=9346, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2375
# >140/200, 315/390, d1=0.641, d2=0.671, g=0.857, secs=9348, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2375
# >140/200, 320/390, d1=0.625, d2=0.634, g=0.888, secs=9350, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2376
# >140/200, 325/390, d1=0.649, d2=0.634, g=0.861, secs=9353, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2376
# >140/200, 330/390, d1=0.626, d2=0.629, g=0.861, secs=9355, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2377
# >140/200, 335/390, d1=0.664, d2=0.640, g=0.865, secs=9357, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2378
# >140/200, 340/390, d1=0.653, d2=0.669, g=0.849, secs=9359, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2378
# >140/200, 345/390, d1=0.646, d2=0.744, g=0.818, secs=9361, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2379
# >140/200, 350/390, d1=0.674, d2=0.648, g=0.863, secs=9363, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2379
# >140/200, 355/390, d1=0.675, d2=0.609, g=0.873, secs=9365, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2380
# >140/200, 360/390, d1=0.632, d2=0.649, g=0.855, secs=9368, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2380
# >140/200, 365/390, d1=0.639, d2=0.678, g=0.876, secs=9370, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2381
# >140/200, 370/390, d1=0.679, d2=0.678, g=0.858, secs=9372, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2381
# >140/200, 375/390, d1=0.655, d2=0.661, g=0.817, secs=9374, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2382
# >140/200, 380/390, d1=0.649, d2=0.669, g=0.853, secs=9376, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2383
# >140/200, 385/390, d1=0.666, d2=0.658, g=0.840, secs=9378, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2383
# >140/200, 390/390, d1=0.623, d2=0.650, g=0.839, secs=9381, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2384
# >Accuracy real: 44%, fake: 82%
# >141/200, 5/390, d1=0.637, d2=0.655, g=0.882, secs=9385, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2384
# >141/200, 10/390, d1=0.654, d2=0.705, g=0.864, secs=9387, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2385
# >141/200, 15/390, d1=0.685, d2=0.650, g=0.855, secs=9389, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2385
# >141/200, 20/390, d1=0.690, d2=0.644, g=0.845, secs=9391, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2386
# >141/200, 25/390, d1=0.682, d2=0.637, g=0.868, secs=9393, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2386
# >141/200, 30/390, d1=0.652, d2=0.682, g=0.856, secs=9395, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2387
# >141/200, 35/390, d1=0.662, d2=0.664, g=0.830, secs=9398, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2388
# >141/200, 40/390, d1=0.639, d2=0.643, g=0.864, secs=9400, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2388
# >141/200, 45/390, d1=0.640, d2=0.681, g=0.873, secs=9402, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2389
# >141/200, 50/390, d1=0.704, d2=0.653, g=0.883, secs=9404, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2389
# >141/200, 55/390, d1=0.686, d2=0.677, g=0.882, secs=9406, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2390
# >141/200, 60/390, d1=0.669, d2=0.654, g=0.888, secs=9408, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2390
# >141/200, 65/390, d1=0.666, d2=0.639, g=0.874, secs=9410, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2391
# >141/200, 70/390, d1=0.611, d2=0.664, g=0.841, secs=9413, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2391
# >141/200, 75/390, d1=0.653, d2=0.657, g=0.824, secs=9415, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2392
# >141/200, 80/390, d1=0.719, d2=0.681, g=0.856, secs=9417, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2393
# >141/200, 85/390, d1=0.660, d2=0.639, g=0.838, secs=9419, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2393
# >141/200, 90/390, d1=0.637, d2=0.670, g=0.860, secs=9421, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2394
# >141/200, 95/390, d1=0.618, d2=0.652, g=0.837, secs=9423, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2394
# >141/200, 100/390, d1=0.665, d2=0.685, g=0.833, secs=9426, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2395
# >141/200, 105/390, d1=0.674, d2=0.611, g=0.871, secs=9428, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2395
# >141/200, 110/390, d1=0.682, d2=0.659, g=0.867, secs=9430, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2396
# >141/200, 115/390, d1=0.616, d2=0.662, g=0.834, secs=9432, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2396
# >141/200, 120/390, d1=0.613, d2=0.678, g=0.843, secs=9434, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2397
# >141/200, 125/390, d1=0.656, d2=0.641, g=0.860, secs=9436, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2398
# >141/200, 130/390, d1=0.699, d2=0.680, g=0.843, secs=9438, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2398
# >141/200, 135/390, d1=0.638, d2=0.662, g=0.834, secs=9441, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2399
# >141/200, 140/390, d1=0.676, d2=0.668, g=0.840, secs=9443, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2399
# >141/200, 145/390, d1=0.697, d2=0.686, g=0.855, secs=9445, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2400
# >141/200, 150/390, d1=0.642, d2=0.654, g=0.883, secs=9447, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2400
# >141/200, 155/390, d1=0.710, d2=0.655, g=0.870, secs=9449, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2401
# >141/200, 160/390, d1=0.697, d2=0.618, g=0.865, secs=9451, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2401
# >141/200, 165/390, d1=0.624, d2=0.719, g=0.838, secs=9453, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2402
# >141/200, 170/390, d1=0.667, d2=0.632, g=0.831, secs=9456, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2403
# >141/200, 175/390, d1=0.698, d2=0.665, g=0.826, secs=9458, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2403
# >141/200, 180/390, d1=0.641, d2=0.645, g=0.899, secs=9460, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2404
# >141/200, 185/390, d1=0.674, d2=0.698, g=0.834, secs=9462, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2404
# >141/200, 190/390, d1=0.638, d2=0.645, g=0.833, secs=9464, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2405
# >141/200, 195/390, d1=0.649, d2=0.655, g=0.847, secs=9466, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2405
# >141/200, 200/390, d1=0.666, d2=0.651, g=0.871, secs=9468, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2406
# >141/200, 205/390, d1=0.629, d2=0.659, g=0.838, secs=9471, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2406
# >141/200, 210/390, d1=0.684, d2=0.691, g=0.871, secs=9473, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2407
# >141/200, 215/390, d1=0.636, d2=0.696, g=0.866, secs=9475, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2408
# >141/200, 220/390, d1=0.635, d2=0.617, g=0.843, secs=9477, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2408
# >141/200, 225/390, d1=0.635, d2=0.669, g=0.833, secs=9479, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2409
# >141/200, 230/390, d1=0.656, d2=0.680, g=0.832, secs=9481, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2409
# >141/200, 235/390, d1=0.658, d2=0.649, g=0.858, secs=9484, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2410
# >141/200, 240/390, d1=0.675, d2=0.643, g=0.848, secs=9486, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2410
# >141/200, 245/390, d1=0.648, d2=0.693, g=0.866, secs=9488, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2411
# >141/200, 250/390, d1=0.601, d2=0.647, g=0.855, secs=9490, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2411
# >141/200, 255/390, d1=0.694, d2=0.677, g=0.840, secs=9492, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2412
# >141/200, 260/390, d1=0.630, d2=0.628, g=0.899, secs=9494, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2413
# >141/200, 265/390, d1=0.643, d2=0.652, g=0.860, secs=9496, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2413
# >141/200, 270/390, d1=0.654, d2=0.627, g=0.868, secs=9499, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2414
# >141/200, 275/390, d1=0.668, d2=0.637, g=0.843, secs=9501, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2414
# >141/200, 280/390, d1=0.663, d2=0.669, g=0.829, secs=9503, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2415
# >141/200, 285/390, d1=0.671, d2=0.651, g=0.867, secs=9505, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2415
# >141/200, 290/390, d1=0.642, d2=0.612, g=0.843, secs=9507, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2416
# >141/200, 295/390, d1=0.637, d2=0.659, g=0.848, secs=9509, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2416
# >141/200, 300/390, d1=0.679, d2=0.656, g=0.855, secs=9511, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2417
# >141/200, 305/390, d1=0.651, d2=0.635, g=0.883, secs=9514, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2418
# >141/200, 310/390, d1=0.647, d2=0.630, g=0.810, secs=9516, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2418
# >141/200, 315/390, d1=0.645, d2=0.644, g=0.825, secs=9518, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2419
# >141/200, 320/390, d1=0.618, d2=0.657, g=0.816, secs=9520, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2419
# >141/200, 325/390, d1=0.667, d2=0.639, g=0.862, secs=9522, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2420
# >141/200, 330/390, d1=0.679, d2=0.622, g=0.871, secs=9524, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2420
# >141/200, 335/390, d1=0.681, d2=0.672, g=0.859, secs=9526, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2421
# >141/200, 340/390, d1=0.651, d2=0.626, g=0.837, secs=9529, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2421
# >141/200, 345/390, d1=0.629, d2=0.633, g=0.872, secs=9531, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2422
# >141/200, 350/390, d1=0.654, d2=0.637, g=0.859, secs=9533, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2423
# >141/200, 355/390, d1=0.673, d2=0.686, g=0.861, secs=9535, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2423
# >141/200, 360/390, d1=0.685, d2=0.615, g=0.860, secs=9537, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2424
# >141/200, 365/390, d1=0.629, d2=0.691, g=0.827, secs=9539, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2424
# >141/200, 370/390, d1=0.685, d2=0.613, g=0.846, secs=9541, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2425
# >141/200, 375/390, d1=0.675, d2=0.640, g=0.863, secs=9544, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2425
# >141/200, 380/390, d1=0.720, d2=0.668, g=0.857, secs=9546, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2426
# >141/200, 385/390, d1=0.681, d2=0.653, g=0.839, secs=9548, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2426
# >141/200, 390/390, d1=0.635, d2=0.691, g=0.857, secs=9550, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2427
# >Accuracy real: 51%, fake: 79%
# >142/200, 5/390, d1=0.660, d2=0.660, g=0.837, secs=9554, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2428
# >142/200, 10/390, d1=0.653, d2=0.656, g=0.845, secs=9556, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2428
# >142/200, 15/390, d1=0.687, d2=0.634, g=0.870, secs=9558, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2429
# >142/200, 20/390, d1=0.648, d2=0.656, g=0.895, secs=9561, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2429
# >142/200, 25/390, d1=0.720, d2=0.637, g=0.849, secs=9563, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2430
# >142/200, 30/390, d1=0.665, d2=0.646, g=0.876, secs=9565, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2430
# >142/200, 35/390, d1=0.662, d2=0.692, g=0.841, secs=9567, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2431
# >142/200, 40/390, d1=0.725, d2=0.671, g=0.859, secs=9569, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2431
# >142/200, 45/390, d1=0.601, d2=0.660, g=0.864, secs=9571, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2432
# >142/200, 50/390, d1=0.635, d2=0.645, g=0.832, secs=9574, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2433
# >142/200, 55/390, d1=0.654, d2=0.676, g=0.872, secs=9576, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2433
# >142/200, 60/390, d1=0.660, d2=0.632, g=0.876, secs=9578, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2434
# >142/200, 65/390, d1=0.668, d2=0.630, g=0.839, secs=9580, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2434
# >142/200, 70/390, d1=0.678, d2=0.656, g=0.844, secs=9582, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2435
# >142/200, 75/390, d1=0.663, d2=0.667, g=0.838, secs=9584, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2435
# >142/200, 80/390, d1=0.697, d2=0.658, g=0.878, secs=9586, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2436
# >142/200, 85/390, d1=0.635, d2=0.630, g=0.879, secs=9588, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2436
# >142/200, 90/390, d1=0.640, d2=0.663, g=0.860, secs=9591, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2437
# >142/200, 95/390, d1=0.661, d2=0.658, g=0.851, secs=9593, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2438
# >142/200, 100/390, d1=0.609, d2=0.685, g=0.861, secs=9595, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2438
# >142/200, 105/390, d1=0.704, d2=0.626, g=0.865, secs=9597, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2439
# >142/200, 110/390, d1=0.661, d2=0.648, g=0.866, secs=9599, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2439
# >142/200, 115/390, d1=0.660, d2=0.653, g=0.831, secs=9601, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2440
# >142/200, 120/390, d1=0.636, d2=0.680, g=0.852, secs=9604, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2440
# >142/200, 125/390, d1=0.699, d2=0.650, g=0.869, secs=9606, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2441
# >142/200, 130/390, d1=0.638, d2=0.671, g=0.840, secs=9608, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2441
# >142/200, 135/390, d1=0.618, d2=0.625, g=0.833, secs=9610, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2442
# >142/200, 140/390, d1=0.614, d2=0.690, g=0.859, secs=9612, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2443
# >142/200, 145/390, d1=0.692, d2=0.625, g=0.832, secs=9614, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2443
# >142/200, 150/390, d1=0.639, d2=0.695, g=0.837, secs=9616, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2444
# >142/200, 155/390, d1=0.624, d2=0.645, g=0.831, secs=9619, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2444
# >142/200, 160/390, d1=0.679, d2=0.633, g=0.875, secs=9621, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2445
# >142/200, 165/390, d1=0.667, d2=0.661, g=0.858, secs=9623, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2445
# >142/200, 170/390, d1=0.641, d2=0.642, g=0.842, secs=9625, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2446
# >142/200, 175/390, d1=0.653, d2=0.638, g=0.854, secs=9627, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2446
# >142/200, 180/390, d1=0.642, d2=0.657, g=0.842, secs=9629, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2447
# >142/200, 185/390, d1=0.650, d2=0.673, g=0.838, secs=9631, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2448
# >142/200, 190/390, d1=0.627, d2=0.647, g=0.847, secs=9634, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2448
# >142/200, 195/390, d1=0.633, d2=0.699, g=0.826, secs=9636, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2449
# >142/200, 200/390, d1=0.650, d2=0.646, g=0.873, secs=9638, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2449
# >142/200, 205/390, d1=0.705, d2=0.660, g=0.894, secs=9640, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2450
# >142/200, 210/390, d1=0.596, d2=0.669, g=0.882, secs=9642, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2450
# >142/200, 215/390, d1=0.654, d2=0.650, g=0.838, secs=9644, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2451
# >142/200, 220/390, d1=0.678, d2=0.663, g=0.868, secs=9646, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2451
# >142/200, 225/390, d1=0.654, d2=0.656, g=0.902, secs=9649, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2452
# >142/200, 230/390, d1=0.660, d2=0.630, g=0.868, secs=9651, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2453
# >142/200, 235/390, d1=0.674, d2=0.612, g=0.888, secs=9653, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2453
# >142/200, 240/390, d1=0.645, d2=0.693, g=0.855, secs=9655, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2454
# >142/200, 245/390, d1=0.669, d2=0.641, g=0.883, secs=9657, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2454
# >142/200, 250/390, d1=0.676, d2=0.677, g=0.835, secs=9659, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2455
# >142/200, 255/390, d1=0.634, d2=0.651, g=0.872, secs=9661, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2455
# >142/200, 260/390, d1=0.685, d2=0.661, g=0.837, secs=9664, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2456
# >142/200, 265/390, d1=0.678, d2=0.637, g=0.880, secs=9666, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2456
# >142/200, 270/390, d1=0.673, d2=0.623, g=0.852, secs=9668, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2457
# >142/200, 275/390, d1=0.695, d2=0.638, g=0.824, secs=9670, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2458
# >142/200, 280/390, d1=0.696, d2=0.675, g=0.881, secs=9672, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2458
# >142/200, 285/390, d1=0.665, d2=0.656, g=0.867, secs=9674, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2459
# >142/200, 290/390, d1=0.635, d2=0.655, g=0.831, secs=9676, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2459
# >142/200, 295/390, d1=0.692, d2=0.657, g=0.838, secs=9679, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2460
# >142/200, 300/390, d1=0.731, d2=0.655, g=0.857, secs=9681, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2460
# >142/200, 305/390, d1=0.660, d2=0.619, g=0.868, secs=9683, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2461
# >142/200, 310/390, d1=0.672, d2=0.636, g=0.859, secs=9685, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2461
# >142/200, 315/390, d1=0.662, d2=0.647, g=0.865, secs=9687, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2462
# >142/200, 320/390, d1=0.655, d2=0.633, g=0.858, secs=9689, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2463
# >142/200, 325/390, d1=0.630, d2=0.673, g=0.857, secs=9692, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2463
# >142/200, 330/390, d1=0.670, d2=0.648, g=0.847, secs=9694, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2464
# >142/200, 335/390, d1=0.682, d2=0.644, g=0.869, secs=9696, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2464
# >142/200, 340/390, d1=0.691, d2=0.625, g=0.872, secs=9698, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2465
# >142/200, 345/390, d1=0.644, d2=0.656, g=0.832, secs=9700, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2465
# >142/200, 350/390, d1=0.729, d2=0.674, g=0.860, secs=9702, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2466
# >142/200, 355/390, d1=0.668, d2=0.654, g=0.876, secs=9704, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2466
# >142/200, 360/390, d1=0.635, d2=0.651, g=0.843, secs=9707, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2467
# >142/200, 365/390, d1=0.629, d2=0.631, g=0.860, secs=9709, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2468
# >142/200, 370/390, d1=0.682, d2=0.702, g=0.891, secs=9711, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2468
# >142/200, 375/390, d1=0.660, d2=0.661, g=0.885, secs=9713, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2469
# >142/200, 380/390, d1=0.654, d2=0.692, g=0.867, secs=9715, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2469
# >142/200, 385/390, d1=0.634, d2=0.648, g=0.878, secs=9717, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2470
# >142/200, 390/390, d1=0.663, d2=0.647, g=0.917, secs=9719, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2470
# >Accuracy real: 52%, fake: 85%
# >143/200, 5/390, d1=0.644, d2=0.621, g=0.832, secs=9724, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2471
# >143/200, 10/390, d1=0.630, d2=0.694, g=0.823, secs=9726, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2471
# >143/200, 15/390, d1=0.698, d2=0.656, g=0.874, secs=9728, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2472
# >143/200, 20/390, d1=0.708, d2=0.652, g=0.852, secs=9730, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2473
# >143/200, 25/390, d1=0.661, d2=0.645, g=0.864, secs=9732, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2473
# >143/200, 30/390, d1=0.655, d2=0.685, g=0.849, secs=9735, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2474
# >143/200, 35/390, d1=0.730, d2=0.651, g=0.865, secs=9737, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2474
# >143/200, 40/390, d1=0.693, d2=0.656, g=0.865, secs=9739, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2475
# >143/200, 45/390, d1=0.696, d2=0.650, g=0.855, secs=9741, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2475
# >143/200, 50/390, d1=0.622, d2=0.681, g=0.853, secs=9743, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2476
# >143/200, 55/390, d1=0.681, d2=0.638, g=0.864, secs=9745, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2476
# >143/200, 60/390, d1=0.705, d2=0.643, g=0.837, secs=9748, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2477
# >143/200, 65/390, d1=0.681, d2=0.651, g=0.847, secs=9750, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2478
# >143/200, 70/390, d1=0.653, d2=0.653, g=0.855, secs=9752, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2478
# >143/200, 75/390, d1=0.648, d2=0.659, g=0.867, secs=9754, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2479
# >143/200, 80/390, d1=0.682, d2=0.650, g=0.836, secs=9756, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2479
# >143/200, 85/390, d1=0.636, d2=0.655, g=0.845, secs=9758, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2480
# >143/200, 90/390, d1=0.657, d2=0.664, g=0.863, secs=9760, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2480
# >143/200, 95/390, d1=0.661, d2=0.620, g=0.846, secs=9763, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2481
# >143/200, 100/390, d1=0.706, d2=0.642, g=0.869, secs=9765, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2481
# >143/200, 105/390, d1=0.627, d2=0.664, g=0.852, secs=9767, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2482
# >143/200, 110/390, d1=0.682, d2=0.654, g=0.853, secs=9769, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2483
# >143/200, 115/390, d1=0.691, d2=0.660, g=0.881, secs=9771, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2483
# >143/200, 120/390, d1=0.659, d2=0.666, g=0.854, secs=9773, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2484
# >143/200, 125/390, d1=0.651, d2=0.650, g=0.820, secs=9775, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2484
# >143/200, 130/390, d1=0.670, d2=0.657, g=0.839, secs=9778, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2485
# >143/200, 135/390, d1=0.674, d2=0.667, g=0.841, secs=9780, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2485
# >143/200, 140/390, d1=0.710, d2=0.617, g=0.885, secs=9782, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2486
# >143/200, 145/390, d1=0.662, d2=0.686, g=0.869, secs=9784, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2486
# >143/200, 150/390, d1=0.584, d2=0.665, g=0.862, secs=9786, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2487
# >143/200, 155/390, d1=0.655, d2=0.707, g=0.851, secs=9788, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2488
# >143/200, 160/390, d1=0.693, d2=0.661, g=0.875, secs=9790, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2488
# >143/200, 165/390, d1=0.597, d2=0.628, g=0.859, secs=9793, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2489
# >143/200, 170/390, d1=0.650, d2=0.635, g=0.867, secs=9795, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2489
# >143/200, 175/390, d1=0.648, d2=0.607, g=0.862, secs=9797, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2490
# >143/200, 180/390, d1=0.671, d2=0.640, g=0.858, secs=9799, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=2490
# ...
# >199/200, 50/390, d1=0.550, d2=0.579, g=0.969, secs=19233, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4903
# >199/200, 55/390, d1=0.667, d2=0.609, g=1.022, secs=19235, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4903
# >199/200, 60/390, d1=0.702, d2=0.568, g=0.936, secs=19237, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4904
# >199/200, 65/390, d1=0.587, d2=0.589, g=1.012, secs=19239, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4904
# >199/200, 70/390, d1=0.668, d2=0.572, g=0.975, secs=19241, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4905
# >199/200, 75/390, d1=0.535, d2=0.639, g=1.047, secs=19243, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4905
# >199/200, 80/390, d1=0.628, d2=0.683, g=1.009, secs=19246, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4906
# >199/200, 85/390, d1=0.637, d2=0.587, g=0.976, secs=19248, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4906
# >199/200, 90/390, d1=0.590, d2=0.634, g=1.014, secs=19250, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4907
# >199/200, 95/390, d1=0.623, d2=0.622, g=1.025, secs=19252, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4908
# >199/200, 100/390, d1=0.632, d2=0.582, g=0.992, secs=19254, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4908
# >199/200, 105/390, d1=0.550, d2=0.627, g=1.029, secs=19256, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4909
# >199/200, 110/390, d1=0.601, d2=0.627, g=0.989, secs=19258, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4909
# >199/200, 115/390, d1=0.568, d2=0.641, g=0.979, secs=19261, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4910
# >199/200, 120/390, d1=0.647, d2=0.617, g=0.983, secs=19263, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4910
# >199/200, 125/390, d1=0.616, d2=0.564, g=1.015, secs=19265, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4911
# >199/200, 130/390, d1=0.692, d2=0.614, g=0.969, secs=19267, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4911
# >199/200, 135/390, d1=0.610, d2=0.620, g=0.959, secs=19269, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4912
# >199/200, 140/390, d1=0.654, d2=0.615, g=0.991, secs=19271, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4913
# >199/200, 145/390, d1=0.621, d2=0.594, g=1.020, secs=19273, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4913
# >199/200, 150/390, d1=0.619, d2=0.581, g=0.996, secs=19275, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4914
# >199/200, 155/390, d1=0.671, d2=0.589, g=0.968, secs=19278, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4914
# >199/200, 160/390, d1=0.652, d2=0.669, g=0.985, secs=19280, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4915
# >199/200, 165/390, d1=0.582, d2=0.558, g=1.032, secs=19282, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4915
# >199/200, 170/390, d1=0.666, d2=0.626, g=0.952, secs=19284, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4916
# >199/200, 175/390, d1=0.613, d2=0.602, g=0.969, secs=19286, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4916
# >199/200, 180/390, d1=0.647, d2=0.601, g=1.061, secs=19288, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4917
# >199/200, 185/390, d1=0.601, d2=0.568, g=1.036, secs=19290, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4918
# >199/200, 190/390, d1=0.668, d2=0.563, g=1.021, secs=19293, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4918
# >199/200, 195/390, d1=0.655, d2=0.630, g=0.977, secs=19295, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4919
# >199/200, 200/390, d1=0.630, d2=0.605, g=1.044, secs=19297, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4919
# >199/200, 205/390, d1=0.523, d2=0.567, g=1.004, secs=19299, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4920
# >199/200, 210/390, d1=0.628, d2=0.598, g=0.958, secs=19301, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4920
# >199/200, 215/390, d1=0.592, d2=0.571, g=1.014, secs=19303, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4921
# >199/200, 220/390, d1=0.635, d2=0.646, g=0.999, secs=19305, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4921
# >199/200, 225/390, d1=0.621, d2=0.599, g=1.052, secs=19307, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4922
# >199/200, 230/390, d1=0.620, d2=0.615, g=1.025, secs=19310, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4923
# >199/200, 235/390, d1=0.649, d2=0.575, g=1.034, secs=19312, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4923
# >199/200, 240/390, d1=0.599, d2=0.619, g=0.996, secs=19314, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4924
# >199/200, 245/390, d1=0.645, d2=0.569, g=1.021, secs=19316, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4924
# >199/200, 250/390, d1=0.612, d2=0.605, g=1.040, secs=19318, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4925
# >199/200, 255/390, d1=0.608, d2=0.601, g=0.971, secs=19320, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4925
# >199/200, 260/390, d1=0.658, d2=0.641, g=1.008, secs=19322, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4926
# >199/200, 265/390, d1=0.622, d2=0.628, g=1.023, secs=19325, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4926
# >199/200, 270/390, d1=0.640, d2=0.631, g=1.002, secs=19327, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4927
# >199/200, 275/390, d1=0.629, d2=0.605, g=1.004, secs=19329, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4928
# >199/200, 280/390, d1=0.638, d2=0.605, g=0.991, secs=19331, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4928
# >199/200, 285/390, d1=0.622, d2=0.610, g=1.053, secs=19333, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4929
# >199/200, 290/390, d1=0.628, d2=0.663, g=1.032, secs=19335, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4929
# >199/200, 295/390, d1=0.669, d2=0.588, g=1.014, secs=19337, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4930
# >199/200, 300/390, d1=0.655, d2=0.611, g=1.063, secs=19339, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4930
# >199/200, 305/390, d1=0.639, d2=0.620, g=1.021, secs=19342, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4931
# >199/200, 310/390, d1=0.653, d2=0.642, g=0.975, secs=19344, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4931
# >199/200, 315/390, d1=0.651, d2=0.598, g=0.956, secs=19346, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4932
# >199/200, 320/390, d1=0.622, d2=0.602, g=0.951, secs=19348, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4933
# >199/200, 325/390, d1=0.613, d2=0.561, g=1.036, secs=19350, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4933
# >199/200, 330/390, d1=0.582, d2=0.571, g=0.987, secs=19352, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4934
# >199/200, 335/390, d1=0.609, d2=0.588, g=1.010, secs=19354, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4934
# >199/200, 340/390, d1=0.618, d2=0.621, g=1.050, secs=19357, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4935
# >199/200, 345/390, d1=0.576, d2=0.576, g=0.971, secs=19359, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4935
# >199/200, 350/390, d1=0.658, d2=0.572, g=0.981, secs=19361, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4936
# >199/200, 355/390, d1=0.626, d2=0.622, g=0.996, secs=19363, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4936
# >199/200, 360/390, d1=0.566, d2=0.649, g=1.011, secs=19365, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4937
# >199/200, 365/390, d1=0.647, d2=0.591, g=0.985, secs=19367, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4938
# >199/200, 370/390, d1=0.692, d2=0.593, g=1.019, secs=19369, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4938
# >199/200, 375/390, d1=0.615, d2=0.526, g=1.019, secs=19372, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4939
# >199/200, 380/390, d1=0.597, d2=0.587, g=1.013, secs=19374, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4939
# >199/200, 385/390, d1=0.647, d2=0.648, g=1.036, secs=19376, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4940
# >199/200, 390/390, d1=0.647, d2=0.589, g=0.977, secs=19378, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4940
# >Accuracy real: 60%, fake: 92%
# >200/200, 5/390, d1=0.630, d2=0.610, g=1.000, secs=19382, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4941
# >200/200, 10/390, d1=0.618, d2=0.561, g=1.031, secs=19384, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4941
# >200/200, 15/390, d1=0.653, d2=0.626, g=0.997, secs=19386, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4942
# >200/200, 20/390, d1=0.611, d2=0.599, g=0.937, secs=19389, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4943
# >200/200, 25/390, d1=0.643, d2=0.590, g=1.035, secs=19391, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4943
# >200/200, 30/390, d1=0.616, d2=0.594, g=0.992, secs=19393, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4944
# >200/200, 35/390, d1=0.545, d2=0.627, g=0.994, secs=19395, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4944
# >200/200, 40/390, d1=0.581, d2=0.545, g=0.998, secs=19397, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4945
# >200/200, 45/390, d1=0.589, d2=0.612, g=1.031, secs=19399, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4945
# >200/200, 50/390, d1=0.702, d2=0.609, g=0.984, secs=19401, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4946
# >200/200, 55/390, d1=0.623, d2=0.608, g=1.013, secs=19403, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4946
# >200/200, 60/390, d1=0.718, d2=0.578, g=0.982, secs=19406, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4947
# >200/200, 65/390, d1=0.702, d2=0.594, g=1.047, secs=19408, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4948
# >200/200, 70/390, d1=0.665, d2=0.584, g=1.045, secs=19410, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4948
# >200/200, 75/390, d1=0.622, d2=0.667, g=1.000, secs=19412, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4949
# >200/200, 80/390, d1=0.639, d2=0.608, g=0.984, secs=19414, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4949
# >200/200, 85/390, d1=0.611, d2=0.661, g=0.957, secs=19416, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4950
# >200/200, 90/390, d1=0.623, d2=0.590, g=0.959, secs=19418, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4950
# >200/200, 95/390, d1=0.600, d2=0.602, g=0.983, secs=19421, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4951
# >200/200, 100/390, d1=0.620, d2=0.579, g=0.990, secs=19423, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4951
# >200/200, 105/390, d1=0.594, d2=0.641, g=1.015, secs=19425, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4952
# >200/200, 110/390, d1=0.690, d2=0.614, g=1.022, secs=19427, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4953
# >200/200, 115/390, d1=0.651, d2=0.596, g=1.011, secs=19429, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4953
# >200/200, 120/390, d1=0.626, d2=0.604, g=0.989, secs=19431, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4954
# >200/200, 125/390, d1=0.605, d2=0.612, g=0.983, secs=19433, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4954
# >200/200, 130/390, d1=0.609, d2=0.599, g=0.971, secs=19435, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4955
# >200/200, 135/390, d1=0.580, d2=0.600, g=0.977, secs=19438, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4955
# >200/200, 140/390, d1=0.609, d2=0.628, g=1.020, secs=19440, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4956
# >200/200, 145/390, d1=0.565, d2=0.622, g=1.018, secs=19442, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4956
# >200/200, 150/390, d1=0.524, d2=0.590, g=0.970, secs=19444, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4957
# >200/200, 155/390, d1=0.632, d2=0.614, g=1.034, secs=19446, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4958
# >200/200, 160/390, d1=0.598, d2=0.652, g=0.967, secs=19448, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4958
# >200/200, 165/390, d1=0.624, d2=0.597, g=1.022, secs=19450, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4959
# >200/200, 170/390, d1=0.650, d2=0.566, g=1.024, secs=19453, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4959
# >200/200, 175/390, d1=0.639, d2=0.584, g=1.019, secs=19455, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4960
# >200/200, 180/390, d1=0.633, d2=0.615, g=1.020, secs=19457, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4960
# >200/200, 185/390, d1=0.631, d2=0.597, g=0.977, secs=19459, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4961
# >200/200, 190/390, d1=0.533, d2=0.660, g=0.925, secs=19461, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4961
# >200/200, 195/390, d1=0.646, d2=0.587, g=1.055, secs=19463, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4962
# >200/200, 200/390, d1=0.607, d2=0.591, g=1.003, secs=19465, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4963
# >200/200, 205/390, d1=0.626, d2=0.599, g=1.022, secs=19468, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4963
# >200/200, 210/390, d1=0.661, d2=0.559, g=1.054, secs=19470, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4964
# >200/200, 215/390, d1=0.538, d2=0.627, g=1.007, secs=19472, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4964
# >200/200, 220/390, d1=0.616, d2=0.569, g=0.988, secs=19474, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4965
# >200/200, 225/390, d1=0.655, d2=0.672, g=1.045, secs=19476, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4965
# >200/200, 230/390, d1=0.633, d2=0.580, g=1.018, secs=19478, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4966
# >200/200, 235/390, d1=0.636, d2=0.628, g=0.991, secs=19480, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4966
# >200/200, 240/390, d1=0.617, d2=0.577, g=0.993, secs=19483, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4967
# >200/200, 245/390, d1=0.623, d2=0.624, g=1.035, secs=19485, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4968
# >200/200, 250/390, d1=0.553, d2=0.640, g=1.000, secs=19487, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4968
# >200/200, 255/390, d1=0.647, d2=0.625, g=0.995, secs=19489, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4969
# >200/200, 260/390, d1=0.574, d2=0.633, g=0.979, secs=19491, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4969
# >200/200, 265/390, d1=0.530, d2=0.576, g=0.978, secs=19493, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4970
# >200/200, 270/390, d1=0.645, d2=0.585, g=1.017, secs=19495, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4970
# >200/200, 275/390, d1=0.552, d2=0.657, g=0.977, secs=19498, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4971
# >200/200, 280/390, d1=0.673, d2=0.583, g=1.014, secs=19500, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4971
# >200/200, 285/390, d1=0.586, d2=0.621, g=1.019, secs=19502, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4972
# >200/200, 290/390, d1=0.594, d2=0.607, g=1.010, secs=19504, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4973
# >200/200, 295/390, d1=0.687, d2=0.650, g=1.024, secs=19506, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4973
# >200/200, 300/390, d1=0.606, d2=0.565, g=1.004, secs=19508, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4974
# >200/200, 305/390, d1=0.582, d2=0.570, g=1.013, secs=19511, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4974
# >200/200, 310/390, d1=0.650, d2=0.606, g=0.960, secs=19513, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4975
# >200/200, 315/390, d1=0.625, d2=0.584, g=0.992, secs=19515, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4975
# >200/200, 320/390, d1=0.569, d2=0.611, g=0.974, secs=19517, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4976
# >200/200, 325/390, d1=0.638, d2=0.556, g=1.082, secs=19519, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4976
# >200/200, 330/390, d1=0.642, d2=0.635, g=1.023, secs=19521, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4977
# >200/200, 335/390, d1=0.704, d2=0.632, g=0.989, secs=19523, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4978
# >200/200, 340/390, d1=0.629, d2=0.677, g=0.981, secs=19525, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4978
# >200/200, 345/390, d1=0.649, d2=0.614, g=0.956, secs=19528, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4979
# >200/200, 350/390, d1=0.558, d2=0.598, g=1.027, secs=19530, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4979
# >200/200, 355/390, d1=0.665, d2=0.622, g=0.958, secs=19532, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4980
# >200/200, 360/390, d1=0.538, d2=0.615, g=0.970, secs=19534, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4980
# >200/200, 365/390, d1=0.642, d2=0.594, g=0.983, secs=19536, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4981
# >200/200, 370/390, d1=0.674, d2=0.623, g=0.997, secs=19538, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4981
# >200/200, 375/390, d1=0.651, d2=0.568, g=1.066, secs=19540, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4982
# >200/200, 380/390, d1=0.628, d2=0.641, g=0.992, secs=19543, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4983
# >200/200, 385/390, d1=0.648, d2=0.562, g=0.988, secs=19545, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4983
# >200/200, 390/390, d1=0.612, d2=0.584, g=0.956, secs=19547, tryAgain=0, nTripsOnSameSavedWts=0, nSaves=4984
# >Accuracy real: 58%, fake: 76%
